# %%
from pathlib import Path
import os

dataset_folder = Path(".") / "dataset"

if not os.path.exists(dataset_folder):
    import utils
    utils.download_dataset()
# Out:
# Fichier correctement téléchargé

# %%
import polars as pl

# %%
data = pl.read_csv("dataset/train.csv")

# %%
data.shape
# Out:
# (1200000, 21)

# %%
data.head()
# Out:
# shape: (5, 21)
# ┌─────┬──────┬────────┬──────────┬───┬─────────┬───────────┬───────────────┬────────────────┐
# │ id  ┆ Age  ┆ Gender ┆ Annual   ┆ … ┆ Smoking ┆ Exercise  ┆ Property Type ┆ Premium Amount │
# │ --- ┆ ---  ┆ ---    ┆ Income   ┆   ┆ Status  ┆ Frequency ┆ ---           ┆ ---            │
# │ i64 ┆ f64  ┆ str    ┆ ---      ┆   ┆ ---     ┆ ---       ┆ str           ┆ f64            │
# │     ┆      ┆        ┆ f64      ┆   ┆ str     ┆ str       ┆               ┆                │
# ╞═════╪══════╪════════╪══════════╪═══╪═════════╪═══════════╪═══════════════╪════════════════╡
# │ 0   ┆ 19.0 ┆ Female ┆ 10049.0  ┆ … ┆ No      ┆ Weekly    ┆ House         ┆ 2869.0         │
# │ 1   ┆ 39.0 ┆ Female ┆ 31678.0  ┆ … ┆ Yes     ┆ Monthly   ┆ House         ┆ 1483.0         │
# │ 2   ┆ 23.0 ┆ Male   ┆ 25602.0  ┆ … ┆ Yes     ┆ Weekly    ┆ House         ┆ 567.0          │
# │ 3   ┆ 21.0 ┆ Male   ┆ 141855.0 ┆ … ┆ Yes     ┆ Daily     ┆ Apartment     ┆ 765.0          │
# │ 4   ┆ 21.0 ┆ Male   ┆ 39651.0  ┆ … ┆ Yes     ┆ Weekly    ┆ House         ┆ 2022.0         │
# └─────┴──────┴────────┴──────────┴───┴─────────┴───────────┴───────────────┴────────────────┘

# %%
data.null_count()
# Out:
# shape: (1, 21)
# ┌─────┬───────┬────────┬────────┬───┬─────────┬───────────┬───────────────┬────────────────┐
# │ id  ┆ Age   ┆ Gender ┆ Annual ┆ … ┆ Smoking ┆ Exercise  ┆ Property Type ┆ Premium Amount │
# │ --- ┆ ---   ┆ ---    ┆ Income ┆   ┆ Status  ┆ Frequency ┆ ---           ┆ ---            │
# │ u32 ┆ u32   ┆ u32    ┆ ---    ┆   ┆ ---     ┆ ---       ┆ u32           ┆ u32            │
# │     ┆       ┆        ┆ u32    ┆   ┆ u32     ┆ u32       ┆               ┆                │
# ╞═════╪═══════╪════════╪════════╪═══╪═════════╪═══════════╪═══════════════╪════════════════╡
# │ 0   ┆ 18705 ┆ 0      ┆ 44949  ┆ … ┆ 0       ┆ 0         ┆ 0             ┆ 0              │
# └─────┴───────┴────────┴────────┴───┴─────────┴───────────┴───────────────┴────────────────┘

# %%
data.describe()
# Out:
# shape: (9, 22)
# ┌───────────┬───────────┬───────────┬─────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ statistic ┆ id        ┆ Age       ┆ Gender  ┆ … ┆ Smoking   ┆ Exercise  ┆ Property  ┆ Premium   │
# │ ---       ┆ ---       ┆ ---       ┆ ---     ┆   ┆ Status    ┆ Frequency ┆ Type      ┆ Amount    │
# │ str       ┆ f64       ┆ f64       ┆ str     ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---       │
# │           ┆           ┆           ┆         ┆   ┆ str       ┆ str       ┆ str       ┆ f64       │
# ╞═══════════╪═══════════╪═══════════╪═════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ count     ┆ 1.2e6     ┆ 1.181295e ┆ 1200000 ┆ … ┆ 1200000   ┆ 1200000   ┆ 1200000   ┆ 1.2e6     │
# │           ┆           ┆ 6         ┆         ┆   ┆           ┆           ┆           ┆           │
# │ null_coun ┆ 0.0       ┆ 18705.0   ┆ 0       ┆ … ┆ 0         ┆ 0         ┆ 0         ┆ 0.0       │
# │ t         ┆           ┆           ┆         ┆   ┆           ┆           ┆           ┆           │
# │ mean      ┆ 599999.5  ┆ 41.145563 ┆ null    ┆ … ┆ null      ┆ null      ┆ null      ┆ 1102.5448 │
# │           ┆           ┆           ┆         ┆   ┆           ┆           ┆           ┆ 22        │
# │ std       ┆ 346410.30 ┆ 13.53995  ┆ null    ┆ … ┆ null      ┆ null      ┆ null      ┆ 864.99885 │
# │           ┆ 5851      ┆           ┆         ┆   ┆           ┆           ┆           ┆ 9         │
# │ min       ┆ 0.0       ┆ 18.0      ┆ Female  ┆ … ┆ No        ┆ Daily     ┆ Apartment ┆ 20.0      │
# │ 25%       ┆ 300000.0  ┆ 30.0      ┆ null    ┆ … ┆ null      ┆ null      ┆ null      ┆ 514.0     │
# │ 50%       ┆ 600000.0  ┆ 41.0      ┆ null    ┆ … ┆ null      ┆ null      ┆ null      ┆ 872.0     │
# │ 75%       ┆ 899999.0  ┆ 53.0      ┆ null    ┆ … ┆ null      ┆ null      ┆ null      ┆ 1509.0    │
# │ max       ┆ 1.199999e ┆ 64.0      ┆ Male    ┆ … ┆ Yes       ┆ Weekly    ┆ House     ┆ 4999.0    │
# │           ┆ 6         ┆           ┆         ┆   ┆           ┆           ┆           ┆           │
# └───────────┴───────────┴───────────┴─────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %%
data["Occupation"].value_counts()
# Out:
# shape: (4, 2)
# ┌───────────────┬────────┐
# │ Occupation    ┆ count  │
# │ ---           ┆ ---    │
# │ str           ┆ u32    │
# ╞═══════════════╪════════╡
# │ Unemployed    ┆ 276530 │
# │ Self-Employed ┆ 282645 │
# │ null          ┆ 358075 │
# │ Employed      ┆ 282750 │
# └───────────────┴────────┘

# %%
data = data.with_columns(
    pl.col("Occupation").fill_null("Unknown")
)

# %%
data["Occupation"].value_counts()
# Out:
# shape: (4, 2)
# ┌───────────────┬────────┐
# │ Occupation    ┆ count  │
# │ ---           ┆ ---    │
# │ str           ┆ u32    │
# ╞═══════════════╪════════╡
# │ Unemployed    ┆ 276530 │
# │ Employed      ┆ 282750 │
# │ Unknown       ┆ 358075 │
# │ Self-Employed ┆ 282645 │
# └───────────────┴────────┘

# %%
data = data.drop(["Policy Start Date", "id", "Customer Feedback", "Credit Score"])

# %%
data = data.drop_nulls()

# %%
data.shape
# Out:
# (663488, 17)

# %%
import polars.selectors as cs

# %%
df = data.to_dummies(cs.string(), separator = "_", drop_first = True)

# %%
df.shape
# Out:
# (663488, 27)

# %%
y = df["Premium Amount"]
X = df.drop("Premium Amount")

# %%
X.shape
# Out:
# (663488, 26)

# %%
X.columns
# Out:
# ['Age',
#  'Gender_Male',
#  'Annual Income',
#  'Marital Status_Divorced',
#  'Marital Status_Single',
#  'Number of Dependents',
#  'Education Level_High School',
#  "Education Level_Master's",
#  'Education Level_PhD',
#  'Occupation_Employed',
#  'Occupation_Unemployed',
#  'Occupation_Unknown',
#  'Health Score',
#  'Location_Rural',
#  'Location_Suburban',
#  'Policy Type_Basic',
#  'Policy Type_Comprehensive',
#  'Previous Claims',
#  'Vehicle Age',
#  'Insurance Duration',
#  'Smoking Status_Yes',
#  'Exercise Frequency_Daily',
#  'Exercise Frequency_Monthly',
#  'Exercise Frequency_Rarely',
#  'Property Type_Apartment',
#  'Property Type_Condo']

# %%
y.shape
# Out:
# (548554,)

# %%
from sklearn.linear_model import LinearRegression

# %%
lin_reg = LinearRegression()
lin_reg.fit(X, y)
# Out:
# LinearRegression()

# %%
lin_reg.coef_
# Out:
# array([-2.24101585e-01,  1.23597610e+00, -3.75336476e-04, -1.49341056e+00,
#        -1.44581241e+00, -8.13941951e-01,  2.71232736e+00, -1.62632120e+00,
#        -2.14443718e+00,  1.79344741e+00, -1.79190550e+00, -1.08447544e+01,
#         9.53496445e-01, -2.57939387e+00, -1.56662927e+00,  2.89523615e+00,
#         2.80013416e+00,  3.98636071e+01, -1.08070879e-02,  1.49194635e-02,
#        -8.62443840e-01,  7.12488839e-01, -1.95621912e-01, -3.46147087e+00,
#         6.34369982e-01, -7.43056539e-01])

# %%
from sklearn.linear_model import ElasticNet
eln_reg = ElasticNet()
eln_reg.fit(X, y)
# Out:
# ElasticNet()

# %%
eln_reg.coef_
# Out:
# array([-2.16842483e-01,  0.00000000e+00, -3.60869672e-04, -0.00000000e+00,
#        -0.00000000e+00, -4.93038096e-01,  2.99631652e-01, -0.00000000e+00,
#        -0.00000000e+00,  7.54678140e-01,  0.00000000e+00, -2.46546347e+00,
#         9.47874605e-01, -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  2.58490655e+01, -0.00000000e+00,  0.00000000e+00,
#        -0.00000000e+00,  0.00000000e+00,  0.00000000e+00, -2.67252992e-01,
#         0.00000000e+00, -0.00000000e+00])

# %%
from sklearn.ensemble import GradientBoostingRegressor
gb_model = GradientBoostingRegressor()
import time
start_time = time.time()
gb_model.fit(X, y)
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 433.4321427345276 seconds ---

# %%
from sklearn.ensemble import AdaBoostRegressor

adab_model = AdaBoostRegressor()
import time
start_time = time.time()
adab_model.fit(X, y)
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 71.66514706611633 seconds ---

# %%
# Enregistrer les modèles
from pathlib import Path
import os
model_location = Path(".").parent / "models"
if not os.path.exists(model_location):
  os.mkdir(model_location)

import pickle

model_export_names = ["LinearReg_Model.pkl", "ElasticNet_Model.pkl", "GradientB_Model.pkl", "AdaBoost_Model.pkl"]

for model, export_name in zip([lin_reg, eln_reg, gb_model, adab_model], model_export_names):
  with open(model_location / export_name, "wb") as f:
    pickle.dump(model, f)
