# %%
from pathlib import Path
import os

dataset_folder = Path(".") / "dataset"

if not os.path.exists(dataset_folder):
    import utils
    utils.download_dataset()

# %%
import polars as pl

# %%
data = pl.read_csv("dataset/train.csv")

# %%
data.shape
# Out:
# (1200000, 21)

# %%
data.head()
# Out:
# shape: (5, 21)
# ┌─────┬──────┬────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ id  ┆ Age  ┆ Gender ┆ Annual    ┆ … ┆ Smoking   ┆ Exercise  ┆ Property  ┆ Premium   │
# │ --- ┆ ---  ┆ ---    ┆ Income    ┆   ┆ Status    ┆ Frequency ┆ Type      ┆ Amount    │
# │ i64 ┆ f64  ┆ str    ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---       │
# │     ┆      ┆        ┆ f64       ┆   ┆ str       ┆ str       ┆ str       ┆ f64       │
# ╞═════╪══════╪════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 0   ┆ 19.0 ┆ Female ┆ 10049.0   ┆ … ┆ No        ┆ Weekly    ┆ House     ┆ 2869.0    │
# │ 1   ┆ 39.0 ┆ Female ┆ 31678.0   ┆ … ┆ Yes       ┆ Monthly   ┆ House     ┆ 1483.0    │
# │ 2   ┆ 23.0 ┆ Male   ┆ 25602.0   ┆ … ┆ Yes       ┆ Weekly    ┆ House     ┆ 567.0     │
# │ 3   ┆ 21.0 ┆ Male   ┆ 141855.0  ┆ … ┆ Yes       ┆ Daily     ┆ Apartment ┆ 765.0     │
# │ 4   ┆ 21.0 ┆ Male   ┆ 39651.0   ┆ … ┆ Yes       ┆ Weekly    ┆ House     ┆ 2022.0    │
# └─────┴──────┴────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %%
data.null_count()
# Out:
# shape: (1, 21)
# ┌─────┬───────┬────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ id  ┆ Age   ┆ Gender ┆ Annual    ┆ … ┆ Smoking   ┆ Exercise  ┆ Property  ┆ Premium  │
# │ --- ┆ ---   ┆ ---    ┆ Income    ┆   ┆ Status    ┆ Frequency ┆ Type      ┆ Amount   │
# │ u32 ┆ u32   ┆ u32    ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---      │
# │     ┆       ┆        ┆ u32       ┆   ┆ u32       ┆ u32       ┆ u32       ┆ u32      │
# ╞═════╪═══════╪════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 0   ┆ 18705 ┆ 0      ┆ 44949     ┆ … ┆ 0         ┆ 0         ┆ 0         ┆ 0        │
# └─────┴───────┴────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
data.describe()
# Out:
# shape: (9, 22)
# ┌──────────┬──────────┬─────────┬─────────┬───┬─────────┬─────────┬─────────┬─────────┐
# │ statisti ┆ id       ┆ Age     ┆ Gender  ┆ … ┆ Smoking ┆ Exercis ┆ Propert ┆ Premium │
# │ c        ┆ ---      ┆ ---     ┆ ---     ┆   ┆ Status  ┆ e Frequ ┆ y Type  ┆ Amount  │
# │ ---      ┆ f64      ┆ f64     ┆ str     ┆   ┆ ---     ┆ ency    ┆ ---     ┆ ---     │
# │ str      ┆          ┆         ┆         ┆   ┆ str     ┆ ---     ┆ str     ┆ f64     │
# │          ┆          ┆         ┆         ┆   ┆         ┆ str     ┆         ┆         │
# ╞══════════╪══════════╪═════════╪═════════╪═══╪═════════╪═════════╪═════════╪═════════╡
# │ count    ┆ 1.2e6    ┆ 1.18129 ┆ 1200000 ┆ … ┆ 1200000 ┆ 1200000 ┆ 1200000 ┆ 1.2e6   │
# │          ┆          ┆ 5e6     ┆         ┆   ┆         ┆         ┆         ┆         │
# │ null_cou ┆ 0.0      ┆ 18705.0 ┆ 0       ┆ … ┆ 0       ┆ 0       ┆ 0       ┆ 0.0     │
# │ nt       ┆          ┆         ┆         ┆   ┆         ┆         ┆         ┆         │
# │ mean     ┆ 599999.5 ┆ 41.1455 ┆ null    ┆ … ┆ null    ┆ null    ┆ null    ┆ 1102.54 │
# │          ┆          ┆ 63      ┆         ┆   ┆         ┆         ┆         ┆ 4822    │
# │ std      ┆ 346410.3 ┆ 13.5399 ┆ null    ┆ … ┆ null    ┆ null    ┆ null    ┆ 864.998 │
# │          ┆ 05851    ┆ 5       ┆         ┆   ┆         ┆         ┆         ┆ 859     │
# │ min      ┆ 0.0      ┆ 18.0    ┆ Female  ┆ … ┆ No      ┆ Daily   ┆ Apartme ┆ 20.0    │
# │          ┆          ┆         ┆         ┆   ┆         ┆         ┆ nt      ┆         │
# │ 25%      ┆ 300000.0 ┆ 30.0    ┆ null    ┆ … ┆ null    ┆ null    ┆ null    ┆ 514.0   │
# │ 50%      ┆ 600000.0 ┆ 41.0    ┆ null    ┆ … ┆ null    ┆ null    ┆ null    ┆ 872.0   │
# │ 75%      ┆ 899999.0 ┆ 53.0    ┆ null    ┆ … ┆ null    ┆ null    ┆ null    ┆ 1509.0  │
# │ max      ┆ 1.199999 ┆ 64.0    ┆ Male    ┆ … ┆ Yes     ┆ Weekly  ┆ House   ┆ 4999.0  │
# │          ┆ e6       ┆         ┆         ┆   ┆         ┆         ┆         ┆         │
# └──────────┴──────────┴─────────┴─────────┴───┴─────────┴─────────┴─────────┴─────────┘

# %%
data["Occupation"].value_counts()
# Out:
# shape: (4, 2)
# ┌───────────────┬────────┐
# │ Occupation    ┆ count  │
# │ ---           ┆ ---    │
# │ str           ┆ u32    │
# ╞═══════════════╪════════╡
# │ null          ┆ 358075 │
# │ Unemployed    ┆ 276530 │
# │ Employed      ┆ 282750 │
# │ Self-Employed ┆ 282645 │
# └───────────────┴────────┘

# %%
data = data.with_columns(
    pl.col("Occupation").fill_null("Unknown")
)

# %%
data["Occupation"].value_counts()
# Out:
# shape: (4, 2)
# ┌───────────────┬────────┐
# │ Occupation    ┆ count  │
# │ ---           ┆ ---    │
# │ str           ┆ u32    │
# ╞═══════════════╪════════╡
# │ Employed      ┆ 282750 │
# │ Self-Employed ┆ 282645 │
# │ Unemployed    ┆ 276530 │
# │ Unknown       ┆ 358075 │
# └───────────────┴────────┘

# %%
data = data.drop_nulls()

# %%
data.shape
# Out:
# (548554, 21)

# %%
import polars.selectors as cs

# %%
data = data.drop(["Policy Start Date", "id", "Customer Feedback", "Credit Score"])

# %%
df = data.to_dummies(cs.string(), separator = "_", drop_first = True)

# %%
df.shape
# Out:
# (548554, 27)

# %%
y = df["Premium Amount"]
X = df.drop("Premium Amount")

# %%
X.shape
# Out:
# (548554, 26)

# %%
y.shape
# Out:
# (548554,)

# %%
from sklearn.linear_model import LinearRegression

# %%
lin_reg = LinearRegression()
lin_reg.fit(X, y)
# Out:
# LinearRegression()

# %%
lin_reg.coef_
# Out:
# array([-2.77797649e-01,  1.62613200e+00, -4.62363209e-04, -2.88799927e+00,
#        -6.10228384e-01, -1.11445651e+00,  2.12504823e+00, -1.82183048e+00,
#        -3.62041707e+00,  4.30559947e+00, -8.86698113e-01, -1.04419543e+01,
#         9.80502118e-01, -3.50578102e+00, -1.22098366e+00,  3.37794519e+00,
#         2.43985350e+00,  4.09160133e+01,  6.91081874e-02, -2.80024171e-02,
#         1.99417758e-01,  3.84854636e-01, -1.58891765e+00, -2.73011101e+00,
#        -2.09027991e+00, -5.08605021e-01])

# %%
from sklearn.linear_model import ElasticNet
eln_reg = ElasticNet()
eln_reg.fit(X, y)
# Out:
# ElasticNet()

# %%
eln_reg.coef_
# Out:
# array([-2.70396468e-01,  0.00000000e+00, -4.51439303e-04, -7.99927292e-02,
#         0.00000000e+00, -7.32378089e-01,  2.67981026e-01, -0.00000000e+00,
#        -2.80457897e-01,  1.28712436e+00,  0.00000000e+00, -2.64054531e+00,
#         9.74596890e-01, -1.85094589e-01,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  2.64827846e+01,  5.18743447e-02, -0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#        -0.00000000e+00,  0.00000000e+00])

# %%
X.head()
# Out:
# shape: (5, 26)
# ┌──────┬──────────┬──────────┬──────────┬───┬──────────┬──────────┬─────────┬─────────┐
# │ Age  ┆ Gender_M ┆ Annual   ┆ Marital  ┆ … ┆ Exercise ┆ Exercise ┆ Propert ┆ Propert │
# │ ---  ┆ ale      ┆ Income   ┆ Status_D ┆   ┆ Frequenc ┆ Frequenc ┆ y Type_ ┆ y Type_ │
# │ f64  ┆ ---      ┆ ---      ┆ ivorced  ┆   ┆ y_Monthl ┆ y_Rarely ┆ Apartme ┆ Condo   │
# │      ┆ u8       ┆ f64      ┆ ---      ┆   ┆ y        ┆ ---      ┆ nt      ┆ ---     │
# │      ┆          ┆          ┆ u8       ┆   ┆ ---      ┆ u8       ┆ ---     ┆ u8      │
# │      ┆          ┆          ┆          ┆   ┆ u8       ┆          ┆ u8      ┆         │
# ╞══════╪══════════╪══════════╪══════════╪═══╪══════════╪══════════╪═════════╪═════════╡
# │ 19.0 ┆ 0        ┆ 10049.0  ┆ 0        ┆ … ┆ 0        ┆ 0        ┆ 0       ┆ 0       │
# │ 39.0 ┆ 0        ┆ 31678.0  ┆ 1        ┆ … ┆ 1        ┆ 0        ┆ 0       ┆ 0       │
# │ 21.0 ┆ 1        ┆ 141855.0 ┆ 0        ┆ … ┆ 0        ┆ 0        ┆ 1       ┆ 0       │
# │ 21.0 ┆ 1        ┆ 39651.0  ┆ 0        ┆ … ┆ 0        ┆ 0        ┆ 0       ┆ 0       │
# │ 29.0 ┆ 1        ┆ 45963.0  ┆ 0        ┆ … ┆ 0        ┆ 0        ┆ 0       ┆ 0       │
# └──────┴──────────┴──────────┴──────────┴───┴──────────┴──────────┴─────────┴─────────┘
