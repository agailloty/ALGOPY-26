# %%
# Lire le fichier

sofifa = ""

with open("response2.html", "r", encoding= "utf-8") as file:
    sofifa = file.read()

# %%
len(sofifa)
# Out:
# 331403

# %%
# Extraire des informations avec lxml
from lxml.html import fromstring

# %%
sofifa_xml = fromstring(sofifa)

# %%
sofifa_xml.xpath('//div[@class="player"]')
# Out:
# []
